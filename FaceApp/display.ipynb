# %%
import cv2

# %%
image = cv2.imread("kid1.jpg")
image2 = cv2.imread("kid2.jpg")

if image is not None:
    cv2.imshow("image showing", image)        # open the window of image
    cv2.waitKey(0)                       # wait for key-- open until press any key
    cv2.destroyAllWindows()              #close when the key is pressed
else:
    print("Opps! image could not found")
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/bilal-ali/Documents/OpenCvApplication/.venv/lib/python3.12/site-packages/cv2/qt/plugins"
