# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
import cv2

face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

cap = cv2.VideoCapture(2)
while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray,1.1, 5)
    
    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255, 0, 2))
        
    cv2.imshow("Webcam Face Dectection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@2353.228] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ERROR:0@2353.229] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 8
#       6 while True:
#       7     ret, frame = cap.read()
# ----> 8     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9     faces = face_cascade.detectMultiScale(gray,1.1, 5)
#      11     for (x,y,w,h) in faces:
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
