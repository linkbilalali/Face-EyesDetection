# %%
import cv2

# %%
image = cv2.imread("kid1.jpg")
           
if image is not None:
    sucess = cv2.imwrite("output.jpg", image)
    if sucess:
        print("image saved sucessfully")
    else:
        print("Image could not saved")   
else:
    print("image could not found")
# Out:
# image saved sucessfully
